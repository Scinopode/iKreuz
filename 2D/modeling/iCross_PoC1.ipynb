# %% [markdown]
# # iCross Proof-of-Concept pt. I
#
# ## Geometry
#
# | Item           | size         |
# | :------------- |:-------------|
# | domain width   | $w=100\,\text{m}$    |
# | domain height  | $h=100\,\text{m}$    |
# | Borehole radius | $r_b=0.78\,\text{m}$|
# | Bentonite thickness | $d_B=1.42\,\text{m}$|
# | Cement thickness | $d_C=0.05\,\text{m}$ |
#
# ## Media properties
# ### Bentonite
#
# Bentonite as the direct artificial barrier surrounding the HLRW-canister
#
# | Quantity | Value |
# | :------------- |-------------:|
# | Porosity | $\phi=0.06$ |
# | Permeability | $K_\mathrm{SR}=1.e-20$|
# | Biot coefficient | $\alpha_B=1.0$ |
# | Characteristic curves | *van Genuchten*|
# | Exponent | $m=0.5$ |
# | Entry pressure | $p_b=5000\,\text{Pa}$ |
#
# ### Bentonite
#
# | Quantity | Value |
# | :------------- |-------------:|
# | Porosity | $\phi=$ |
# | Permeability | $K_\mathrm{SR}=$|
# | Biot coefficient | $\alpha_B=$ |
# | Characteristic curves | *van Genuchten*|
# | Exponent | $m=$ |
# | Entry pressure | $p_b=\,\text{Pa}$ |
#
#
# Markdown | Less | Pretty
# --- | --- | ---
# *Still* | `renders` | **nicely**
# 1 | 2 | 3

# %%
import numpy as np
import matplotlib.pyplot as plt

# Grunwald Model
# p_cap = np.logspace(0, 4, 20)
p_cap = np.arange(0, 10000, 10)
p_max = 10000
lambda_ = 2
s_eff_G = np.minimum(1,np.maximum(0,1-(p_cap/p_max)**lambda_))

# %%
plt.yscale('log')
plt.plot(s_eff_G, p_cap, 'y-')


plt.show()

# %%
from IPython.display import Markdown as md

x=45

md("The data consists of {} observations. <br/> Bla, Bla, ....".format(x))
# Out:
# The data consists of 45 observations. <br/> Bla, Bla, ....
